# %%
import pandas as pd

# %%
citi202005_data = pd.read_csv("Raw_Data/JC-202005-citibike-tripdata.csv")

# %%
citi202005_data
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1               138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2               229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3               261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4               168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
# ...             ...                       ...                       ...
# 25072           395  2020-05-31 23:35:50.9460  2020-05-31 23:42:26.5300
# 25073          1681  2020-05-31 23:38:30.8240  2020-06-01 00:06:32.0360
# 25074          1657  2020-05-31 23:39:07.2680  2020-06-01 00:06:44.5740
# 25075           420  2020-05-31 23:45:28.3290  2020-05-31 23:52:28.3680
# 25076            87  2020-05-31 23:50:55.8390  2020-05-31 23:52:23.0920
#
#        start station id          start station name  start station latitude  \
# ...

# %%
#Extract the date of the start and end time
citi202005_data['start_date'] = pd.to_datetime(citi202005_data['starttime'])
citi202005_data['start_date'] = citi202005_data['start_date'].dt.date

citi202005_data['end_date'] = pd.to_datetime(citi202005_data['stoptime'])
citi202005_data['end_date'] = citi202005_data['end_date'].dt.date

citi202005_data
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1               138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2               229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3               261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4               168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
# ...             ...                       ...                       ...
# 25072           395  2020-05-31 23:35:50.9460  2020-05-31 23:42:26.5300
# 25073          1681  2020-05-31 23:38:30.8240  2020-06-01 00:06:32.0360
# 25074          1657  2020-05-31 23:39:07.2680  2020-06-01 00:06:44.5740
# 25075           420  2020-05-31 23:45:28.3290  2020-05-31 23:52:28.3680
# 25076            87  2020-05-31 23:50:55.8390  2020-05-31 23:52:23.0920
#
#        start station id          start station name  start station latitude  \
# ...

# %%
#Add Age field given the current year is 2020
citi202005_data["2020_Age"] = 2020 - citi202005_data["birth year"]
citi202005_data
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1               138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2               229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3               261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4               168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
# ...             ...                       ...                       ...
# 25072           395  2020-05-31 23:35:50.9460  2020-05-31 23:42:26.5300
# 25073          1681  2020-05-31 23:38:30.8240  2020-06-01 00:06:32.0360
# 25074          1657  2020-05-31 23:39:07.2680  2020-06-01 00:06:44.5740
# 25075           420  2020-05-31 23:45:28.3290  2020-05-31 23:52:28.3680
# 25076            87  2020-05-31 23:50:55.8390  2020-05-31 23:52:23.0920
#
#        start station id          start station name  start station latitude  \
# ...

# %%
##Trip duration isn't right, need to correct this!
citi202005_data["Duration(mins)"] = citi202005_data["tripduration"]/60
citi202005_data["Duration(hrs)"] = citi202005_data["Duration(mins)"]/60
citi202005_data
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1               138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2               229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3               261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4               168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
# ...             ...                       ...                       ...
# 25072           395  2020-05-31 23:35:50.9460  2020-05-31 23:42:26.5300
# 25073          1681  2020-05-31 23:38:30.8240  2020-06-01 00:06:32.0360
# 25074          1657  2020-05-31 23:39:07.2680  2020-06-01 00:06:44.5740
# 25075           420  2020-05-31 23:45:28.3290  2020-05-31 23:52:28.3680
# 25076            87  2020-05-31 23:50:55.8390  2020-05-31 23:52:23.0920
#
#        start station id          start station name  start station latitude  \
# ...

# %%
#Gender (Zero=unknown; 1=male; 2=female)

# %%
#Put coordinates together for heatmap

citi202005_data['start_coord']= citi202005_data[["start station latitude","start station longitude"]].agg(','.join, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e8aa3ef63b55> in <module>
# ----> 1 citi202005_data['start_coord']= citi202005_data[["start station latitude","start station longitude"]].agg(','.join, axis=1)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in aggregate(self, func, axis, *args, **kwargs)
#    6699             pass
#    6700         if result is None:
# -> 6701             return self.apply(func, axis=axis, args=args, **kwargs)
#    6702         return result
#    6703
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ...
